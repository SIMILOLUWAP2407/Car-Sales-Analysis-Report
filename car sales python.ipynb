# %%
# NAMES and MAILS OF GROUP MEMBERS 

# CHINWEIKE FAVOUR CHINCHEREM  favourchinecherem71@gmail.com
# EZEH FANKLIN EMEKA           Ezehfranklin12@gmail.com
# AYOOLUWA SIMILOLUWA PRAISE   ayooluwasimiloluwa7@gmail.com
# ONWUEMELE CHIOMA HARRIET     harrietonwuemele@gmail.com

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importing CSV File
file_loc ='Car_sales.csv'
data= pd.read_csv(file_loc)

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  Year resale value Vehicle_type  \
# 0          Acura  Integra              16.919          16.360000    Passenger
# 1          Acura       TL              39.384          19.875000    Passenger
# 3          Acura       RL               8.588          29.725000    Passenger
# 4           Audi       A4              20.397          22.255000    Passenger
# 5           Audi       A6              18.780          23.555000    Passenger
# ..           ...      ...                 ...                ...          ...
# 152        Volvo      V40               3.545          18.072975    Passenger
# 153        Volvo      S70              15.245          18.072975    Passenger
# 154        Volvo      V70              17.531          18.072975    Passenger
# 155        Volvo      C70               3.493          18.072975    Passenger
# 156        Volvo      S80              18.969          18.072975    Passenger
#
# ...

# %%
#1. No. of rows and columns in the data set
#--for rows
data.shape[0]
# Out:
# 157

# %%
#--for columns
data.shape[1]
# Out:
# 16

# %%
#1.Number of rows and columns in a dataset
No_of_rows=len(data.index)
No_of_columns= len(data.columns)

print(f"No. of rows is:{No_of_rows}")
print(f"No. of columns is:{No_of_columns}")
# Out:
# No. of rows is:157
# No. of columns is:16

# %%
#2 data types of each column
data.dtypes
# Out:
# Manufacturer                  object
# Model                         object
# Sales_in_thousands           float64
# Year resale value            float64
# Vehicle_type                  object
# Price_in_thousands           float64
# Engine_size                  float64
# Horsepower                   float64
# Wheelbase                    float64
# Width                        float64
# Length                       float64
# Curb_weight                  float64
# Fuel_capacity                float64
# Fuel_efficiency              float64
# Latest_Launch         datetime64[ns]
# Power_perf_factor            float64
# dtype: object

# %%
#3.Filling empty spaces in the database. 
# Counting the number of missing value in the dataset
data.isnull().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64

# %%
#3b Finding average year_resale_value
average_ysv = data['__year_resale_value'].mean()

# %%
average_ysv
# Out:
# 18.072975206611574

# %%
#3c Replace missing year resale value with average year resale value
data['__year_resale_value'] =data['__year_resale_value'].replace(np.nan, average_ysv)

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919            16.360000
# 1          Acura       TL              39.384            19.875000
# 2          Acura       CL              14.114            18.225000
# 3          Acura       RL               8.588            29.725000
# 4           Audi       A4              20.397            22.255000
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545            18.072975
# 153        Volvo      S70              15.245            18.072975
# 154        Volvo      V70              17.531            18.072975
# 155        Volvo      C70               3.493            18.072975
# 156        Volvo      S80              18.969            18.072975
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
#Drop rows with Missing Values in the dataset
data.dropna(inplace=True)

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919            16.360000
# 1          Acura       TL              39.384            19.875000
# 3          Acura       RL               8.588            29.725000
# 4           Audi       A4              20.397            22.255000
# 5           Audi       A6              18.780            23.555000
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545            18.072975
# 153        Volvo      S70              15.245            18.072975
# 154        Volvo      V70              17.531            18.072975
# 155        Volvo      C70               3.493            18.072975
# 156        Volvo      S80              18.969            18.072975
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
#4a. Cleaning the column name '_year_resale_value'
data.rename(columns={'__year_resale_value':'Year resale value'}, inplace=True)

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  Year resale value Vehicle_type  \
# 0          Acura  Integra              16.919          16.360000    Passenger
# 1          Acura       TL              39.384          19.875000    Passenger
# 3          Acura       RL               8.588          29.725000    Passenger
# 4           Audi       A4              20.397          22.255000    Passenger
# 5           Audi       A6              18.780          23.555000    Passenger
# ..           ...      ...                 ...                ...          ...
# 152        Volvo      V40               3.545          18.072975    Passenger
# 153        Volvo      S70              15.245          18.072975    Passenger
# 154        Volvo      V70              17.531          18.072975    Passenger
# 155        Volvo      C70               3.493          18.072975    Passenger
# 156        Volvo      S80              18.969          18.072975    Passenger
#
# ...

# %%
#4b. Performing descriptive statistics of the numerical columns
data.describe()
# Out:
#        Sales_in_thousands  Year resale value  Price_in_thousands  Engine_size  \
# count          152.000000         152.000000          152.000000   152.000000
# mean            53.359072          18.041080           27.331822     3.049342
# std             68.938380          10.172085           14.418669     1.049818
# min              0.110000           5.160000            9.235000     1.000000
# 25%             13.714000          12.527500           17.888750     2.300000
# 50%             29.213000          17.425000           22.747000     3.000000
# 75%             68.069750          18.072975           31.938750     3.575000
# max            540.561000          67.550000           85.500000     8.000000
#
#        Horsepower   Wheelbase       Width      Length  Curb_weight  \
# count  152.000000  152.000000  152.000000  152.000000   152.000000
# mean   184.809211  107.413816   71.088816  187.059211     3.376184
# ...

# %%
Described =pd.DataFrame([mean_sources,median_sources,std_sources], index=['Mean','Median','Standard Deviation'])

# %%
Described
# Out:
#                     Sales_in_thousands  Year resale value  Price_in_thousands  \
# Mean                         53.359072          18.041080           27.331822
# Median                       29.213000          17.425000           22.747000
# Standard Deviation           68.938380          10.172085           14.418669
#
#                     Engine_size  Horsepower   Wheelbase      Width  \
# Mean                   3.049342  184.809211  107.413816  71.088816
# Median                 3.000000  175.000000  107.000000  70.400000
# Standard Deviation     1.049818   56.823152    7.717839   3.464666
#
#                         Length  Curb_weight  Fuel_capacity  Fuel_efficiency  \
# Mean                187.059211     3.376184      17.959211        23.842105
# Median              186.650000     3.336000      17.200000        24.000000
# Standard Deviation   13.471247     0.636593       3.937582         4.304788
#
#                     Power_perf_factor
# ...

# %%
#5. checking for duplicates
data.duplicated().sum()
# Out:
# 0

# %%
PV1= data.pivot_table(index='Manufacturer', values='Sales_in_thousands', aggfunc='mean')
PV1.sort_values(by='Sales_in_thousands', ascending=False)
# Out:
#               Sales_in_thousands
# Manufacturer
# Ford                  183.875909
# Honda                 118.534800
# Jeep                   97.717667
# Toyota                 82.245000
# Dodge                  82.212100
# Pontiac                61.755667
# Chevrolet              61.596111
# Buick                  60.504750
# Nissan                 57.090714
# Hyundai                45.775333
# Subaru                 40.067500
# Mercury                39.666500
# Volkswagen             34.868667
# Saturn                 33.770000
# Lincoln                28.544667
# Oldsmobile             28.087000
# Mitsubishi             25.842143
# Chrysler               24.706833
# Cadillac               24.058750
# Infiniti               23.713000
# Acura                  21.630333
# Lexus                  17.807167
# Plymouth               16.000250
# BMW                    15.501667
# Jaguar                 15.467000
# Audi                   13.519000
# Mercedes-B             13.013889
# ...

# %%
#6a. Manufacturer with the highest and lowest average sales volume
#Highest
data.groupby('Manufacturer')['Sales_in_thousands'].mean().sort_values(ascending=False)
# Out:
# Manufacturer
# Ford          183.875909
# Honda         118.534800
# Jeep           97.717667
# Toyota         82.245000
# Dodge          82.212100
# Pontiac        61.755667
# Chevrolet      61.596111
# Buick          60.504750
# Nissan         57.090714
# Hyundai        45.775333
# Subaru         40.067500
# Mercury        39.666500
# Volkswagen     34.868667
# Saturn         33.770000
# Lincoln        28.544667
# Oldsmobile     28.087000
# Mitsubishi     25.842143
# Chrysler       24.706833
# Cadillac       24.058750
# Infiniti       23.713000
# Acura          21.630333
# Lexus          17.807167
# Plymouth       16.000250
# BMW            15.501667
# Jaguar         15.467000
# Audi           13.519000
# Mercedes-B     13.013889
# Volvo          12.623333
# Saab           10.653000
# Porsche         4.042667
# Name: Sales_in_thousands, dtype: float64

# %%
#6b.Lowest
data.groupby('Manufacturer')['Sales_in_thousands'].mean().sort_values(ascending=True)
# Out:
# Manufacturer
# Porsche         4.042667
# Saab           10.653000
# Volvo          12.623333
# Mercedes-B     13.013889
# Audi           13.519000
# Jaguar         15.467000
# BMW            15.501667
# Plymouth       16.000250
# Lexus          17.807167
# Acura          21.630333
# Infiniti       23.713000
# Cadillac       24.058750
# Chrysler       24.706833
# Mitsubishi     25.842143
# Oldsmobile     28.087000
# Lincoln        28.544667
# Saturn         33.770000
# Volkswagen     34.868667
# Mercury        39.666500
# Subaru         40.067500
# Hyundai        45.775333
# Nissan         57.090714
# Buick          60.504750
# Chevrolet      61.596111
# Pontiac        61.755667
# Dodge          82.212100
# Toyota         82.245000
# Jeep           97.717667
# Honda         118.534800
# Ford          183.875909
# Name: Sales_in_thousands, dtype: float64

# %%
#7. Distribution of car prices in the dataset
pivot1 = data.pivot_table(index='Manufacturer', values='Price_in_thousands', aggfunc='sum')
pivot1
pivot1.plot(kind='bar', figsize=(8,4))
plt.xlabel('Manufacturer')
plt.ylabel('Sum of Prices')
plt.title('Distribution of Car Prices')
plt.show()

# %%
#8a. correlation matrix to see if different numerical variables in the dataset correlate with each other
data_correlation=data.corr()

# %%
data_correlation
# Out:
#                     Sales_in_thousands  Year resale value  Price_in_thousands  \
# Sales_in_thousands            1.000000          -0.263100           -0.301850
# Year resale value            -0.263100           1.000000            0.821509
# Price_in_thousands           -0.301850           0.821509            1.000000
# Engine_size                   0.027716           0.464424            0.623545
# Horsepower                   -0.192519           0.698899            0.841062
# Wheelbase                     0.360186          -0.049046            0.108494
# Width                         0.143664           0.158984            0.328493
# Length                        0.260162           0.022725            0.154924
# Curb_weight                   0.008784           0.298945            0.527148
# Fuel_capacity                 0.087437           0.274457            0.423980
# Fuel_efficiency              -0.016474          -0.357530           -0.491391
# ...

# %%
#8b. Plotting the correlation
plt.figure(figsize=(10,8))
sns.heatmap(data_correlation, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
#9. Plot a relationship between price and latest launch year
data['Latest_Launch']=data['Latest_Launch'].astype('datetime64[ns]')

# %%
pivot1 = data.pivot_table(index='Latest_Launch', values='Price_in_thousands', aggfunc='sum')
pivot1
pivot1.plot(kind='line', figsize=(8,4))
plt.xlabel('Latest_Launch')
plt.ylabel('Sum of Prices')
plt.title('Relationship Between price &Latest Launch')
plt.show()

# %%
#10a. Grouping cars by manufacturers
data.groupby('Manufacturer')['Price_in_thousands'].mean()
# Out:
# Manufacturer
# Acura         30.633333
# Audi          39.980000
# BMW           33.096667
# Buick         26.781250
# Cadillac      39.198750
# Chevrolet     20.022778
# Chrysler      23.430833
# Dodge         24.384500
# Ford          21.047273
# Honda         20.277000
# Hyundai       12.165667
# Infiniti      29.465000
# Jaguar        42.800000
# Jeep          20.991667
# Lexus         44.055000
# Lincoln       41.690000
# Mercedes-B    52.916667
# Mercury       20.748333
# Mitsubishi    22.167429
# Nissan        22.360714
# Oldsmobile    25.917400
# Plymouth      22.642500
# Pontiac       22.949167
# Porsche       62.473333
# Saab          29.610000
# Saturn        14.271000
# Subaru        21.395000
# Toyota        21.982889
# Volkswagen    17.698333
# Volvo         30.933333
# Name: Price_in_thousands, dtype: float64

# %%
#10b. Analysis by car prices and fuel efficiency
data.groupby('Manufacturer')['Fuel_efficiency'].mean()
# Out:
# Manufacturer
# Acura         25.000000
# Audi          23.333333
# BMW           25.000000
# Buick         24.250000
# Cadillac      20.250000
# Chevrolet     28.444444
# Chrysler      24.500000
# Dodge         20.100000
# Ford          22.818182
# Honda         25.000000
# Hyundai       27.666667
# Infiniti      25.000000
# Jaguar        21.000000
# Jeep          18.666667
# Lexus         20.833333
# Lincoln       19.333333
# Mercedes-B    23.444444
# Mercury       23.666667
# Mitsubishi    22.857143
# Nissan        22.285714
# Oldsmobile    23.000000
# Plymouth      25.250000
# Pontiac       24.833333
# Porsche       22.000000
# Saab          23.000000
# Saturn        30.400000
# Subaru        24.500000
# Toyota        25.222222
# Volkswagen    26.166667
# Volvo         24.500000
# Name: Fuel_efficiency, dtype: float64

# %%
#11.Analysis and visualization of most popular Car Brands
pivot1 = data.pivot_table(index='Manufacturer', values='Sales_in_thousands', aggfunc='sum')
pivot1
pivot1.plot(kind='bar', figsize=(8,4))
plt.xlabel('Manufacturer')
plt.ylabel('Sum of Sales')
plt.title('Most Popular Brand')
plt.show()

# %%
#12 Car Price with highest resale value compared with its initial price  
data.groupby('Model')['Year resale value'].mean().idxmax()
# Out:
# 'Carrera Cabrio'

# %%
#13a. Top 3 fuel_efficient cars with an engine size 2.5
#filtering cars with engine sizes above 2.5 litres
filtered_data= data[data['Engine_size'] >2.5]
filtered_data
# Out:
#     Manufacturer         Model  Sales_in_thousands  Year resale value  \
# 1          Acura            TL              39.384          19.875000
# 3          Acura            RL               8.588          29.725000
# 5           Audi            A6              18.780          23.555000
# 6           Audi            A8               1.380          39.000000
# 8            BMW          328i               9.231          28.675000
# ..           ...           ...                 ...                ...
# 138       Toyota        Avalon              63.849          18.140000
# 141       Toyota        Sienna              65.119          18.072975
# 143       Toyota       4Runner              68.411          19.425000
# 144       Toyota  Land Cruiser               9.835          34.080000
# 156        Volvo           S80              18.969          18.072975
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %%
#13b. Sorting by fuel efficiency and selecting the top 3
top_3_fuel_efficient_cars = filtered_data.sort_values(by='Fuel_efficiency',ascending=False).head(3)
top_3_fuel_efficient_cars
# Out:
#    Manufacturer        Model  Sales_in_thousands  Year resale value  \
# 27    Chevrolet       Impala             107.995          18.072975
# 22    Chevrolet  Monte Carlo              42.593          11.525000
# 98   Mercedes-B    CLK Coupe              11.592          18.072975
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 27    Passenger               18.89          3.4       180.0      110.5
# 22    Passenger               19.39          3.4       180.0      110.5
# 98    Passenger               41.60          3.2       215.0      105.9
#
#     Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 27   73.0   200.0        3.389           17.0             27.0    2011-06-18
# 22   72.7   197.9        3.340           17.0             27.0    2011-12-22
# 98   67.8   180.3        3.213           16.4             26.0    2011-07-08
#
#     Power_perf_factor
# 27          71.838039
# 22          72.030917
# ...

# %%
(top_3_fuel_efficient_cars['Model'])
# Out:
# 27         Impala
# 22    Monte Carlo
# 98      CLK Coupe
# Name: Model, dtype: object

# %%
#14 Lexus model with highest horsepower
#filtering for lexus models
lexus_data = data[data['Manufacturer']== 'Lexus']
lexus_data
# Out:
#    Manufacturer  Model  Sales_in_thousands  Year resale value Vehicle_type  \
# 70        Lexus  ES300              24.072          26.975000    Passenger
# 71        Lexus  GS300              12.698          32.075000    Passenger
# 72        Lexus  GS400               3.334          18.072975    Passenger
# 73        Lexus  LS400               6.375          40.375000    Passenger
# 74        Lexus  LX470               9.126          18.072975          Car
# 75        Lexus  RX300              51.238          18.072975          Car
#
#     Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 70              31.505          3.0       210.0      105.1   70.5   190.2
# 71              37.805          3.0       225.0      110.2   70.9   189.2
# 72              46.305          4.0       300.0      110.2   70.9   189.2
# 73              54.005          4.0       290.0      112.2   72.0   196.7
# ...

# %%
#Lexus model with the highest horsepower
highest_lexus_hp_model = lexus_data.loc[lexus_data['Horsepower'].idxmax()]
print("Lexus model with the highest horsepower")
(highest_lexus_hp_model['Model'])
# Out:
# Lexus model with the highest horsepower
# 'GS400'
